# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint 
# %matplotlib inline
import matplotlip as npl
label_size = 14
mpl.rcParams["xtick.labelsize"]= label_size
mpl.rcParams["ytick.labelsinze"]= label_size
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-05ade7086a21> in <module>()
#       3 from scipy.integrate import odeint
#       4 get_ipython().magic('matplotlib inline')
# ----> 5 import matplotlip as npl
#       6 label_size = 14
#       7 mpl.rcParams["xtick.labelsize"]= label_size
#
# ModuleNotFoundError: No module named 'matplotlip'

# %%
k= 3.0 # constante muelle
m= 1.0 # masa
B= .5 # constante de amortiguacion

def armonico (variables, t):
    x, y= variables
    return [y, -k * x / m-B / m * y]
inicial= [ 0.6,0.4]# vector de posicio inicial  y velocidad inical 
# condiciones inicales  x(t=0)=0.6 [m]  y (t=0)=0.4 [m/s]

#tiempo =np.linspace(0,15) # dominio temporal de 0 a 15
tiempo = np.arange(0, 20, .01)

resultado=odeint(armonico, inicial, tiempo)
# el sistema se resulve con 
#odeint(sistema, condiciones iniciales , rango donde graficaremos)

# %%
xx, yy = resultado.T #extraer posicion y velocidad

# %%
import matplotlib as mpl
label_size = 14
mpl.rcParams['xtick.labelsize'] = label_size 
mpl.rcParams['ytick.labelsize'] = label_size

# %%
plt.plot(tiempo, xx, c = 'r', label="Posicion") 
plt.plot(tiempo, yy, c = 'k', label="Velocidad")
plt.legend(loc = 'best', prop={'size': 14})    
plt.xlabel('tiempo', fontsize = 14) 
plt.show()

# %%
omega0 = k/m
Gamma = B/(2*m)

# %%
omega0**2, Gamma**2
# Out:
# (9.0, 0.0625)

# %%
omega0**2 > Gamma**2
# Out:
# True

# %%
omega0 = k/m

# %%
plt.figure(figsize = (6,6))
plt.scatter(xx, yy/omega0, lw = 0, s = 3, cmap = 'viridis', c = xx)
plt.show()

# %%
k = .1 # Constante del muelle
m = 1.0   # Masa
B = .5 # Constante de amortiguación

# %%
omega0 = k/m
Gamma = B/(2*m)

# %%
omega0**2, Gamma**2
# Out:
# (0.010000000000000002, 0.0625)

# %%
omega0**2 < Gamma**2
# Out:
# True

# %%
inicial = [0.6, 0.4] 
tiempo = np.arange(0, 20, .01)
resultado = odeint(armonico, inicial, tiempo)

# %%
xxA, yyA = resultado.T  # extraer posición y velocidad.

# %%
plt.plot(tiempo, xxA, c = 'r', label="Posicion") 
plt.plot(tiempo, yyA, c = 'k', label="Velocidad")
plt.legend(loc = 'best', prop={'size': 14})    
plt.xlabel('tiempo', fontsize = 14) 
plt.show()
