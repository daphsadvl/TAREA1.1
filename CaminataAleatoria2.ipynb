# %%
# %matplotlib inline 

import numpy as np
import matplotlib.pyplot as plt
import random

# %%
                      x_0 = 0 # inicial al caminador
elements = [1, - 1] # aguila o sol
probabilites = [.5, .5]# p(aguila) = .5 p(sol) = .5
delta_x = np.random.choice(elements, 100, p=probabilites)

y = np.ones(len(np.cumsum(delta_x)))
#plt.plot(np.cumsum(delta_x), y)
plt.plot(np.cumsum(delta_x))

# %%
def walker():
    global x,y
    eleccion=random.randint(0,3)
    if eleccion == 0:
        x+=1
    elif eleccion == 1:
        x-=1
    elif eleccion == 2:
        y+=1
    else:
        y-=1
    return [x,y]
x=0 #iniciar el caminador
y=0

Pos= np.zeros((2,1000))


for i in np.arange(0, len(Pos [0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
def walker():
    global x,y
    x +=random.randint(-1,1)
    y +=random.randint(-1,1)
    return [x,y]

x=0 #iniciar el caminador
y=0

Pos= np.zeros((2,1000))


for i in np.arange(0, len(Pos [0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
def walker():
    global x,y
    x +=random.uniform(-1,1)
    y +=random.uniform(-1,1)
    return [x,y]

x=0 #iniciar el caminador
y=0

Pos= np.zeros((2,1000))


for i in np.arange(0, len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %% [markdown]
# # mejorando el codigo

# %%
X_0= np.array([[0],[0]])
delta_x = np.random.uniform(-1,1,(100))

X= np.concatenate( (X_0, np.cumsum(delta_x, axis = 1)), axis=1 )
rw= plt.plot(X[0],X[1],"ro-")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-ac7a8591cb19> in <module>()
#       2 delta_x = np.random.uniform(-1,1,(100))
#       3
# ----> 4 X= np.concatenate( (X_0, np.cumsum(delta_x, axis = 1)), axis=1 )
#       5 rw= plt.plot(X[0],X[1],"ro-")
#
# C:\Users\EDUARDO\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in cumsum(a, axis, dtype, out)
#    2095
#    2096     """
# -> 2097     return _wrapfunc(a, 'cumsum', axis=axis, dtype=dtype, out=out)
#    2098
#    2099
#
# C:\Users\EDUARDO\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55 def _wrapfunc(obj, method, *args, **kwds):
#      56     try:
# ---> 57         return getattr(obj, method)(*args, **kwds)
#      58
#      59     # An AttributeError occurs if the object does not have
#
# ValueError: axis(=1) out of bounds

# %%
def walker():
    global x,y
    eleccion=random.uniform(0,1)
    if eleccion < 0.40:
        x+=1
    elif eleccion < 0.60:
        x-=1
    elif eleccion < 0.8 :
        y+=1
    else:
        y-=1
    return [x,y]
x=0 #iniciar el caminador
y=0

Pos= np.zeros((2,1000))



for i in np.arange(0, len(Pos [0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %% [markdown]
# # desafio clase

# %%
def walker():
    global x,y
    eleccion=random.uniform(0,1)
    if eleccion < 0.10:
        x+=1
    elif eleccion < 0.10:
        x-=1
    elif eleccion < 0.8 :
        y+=1
    else:
        y-=1
    return [x,y]
x=0 #iniciar el caminador
y=0

Pos= np.zeros((2,1000))



for i in np.arange(0, len(Pos [0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
def walker():
    global x,y
    x +=np.random.normal(0,2000)
    y +=random.gauss(0,2000)
    return [x,y]

x=0 #iniciar el caminador
y=0

Pos= np.zeros((2,100))


for i in np.arange(0, len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
def walker():
    global x,y
    eleccion=random.uniform(0,1)
    if r < 0.01: #un 1% de probbilidad de tomar un paso grande
        x += np.random.normal(0,200)
        y += random.gauss(0,200)
    else:
        x += np.random.normal(0,1)
        y += random.gauss(0,1)   
        
    return [x,y]
x=0 #iniciar el caminador
y=0

Pos= np.zeros((2,1000))



for i in np.arange(0,len(Pos [0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-94cb12790c57> in <module>()
#      19
#      20 for i in np.arange(0,len(Pos [0]),1):
# ---> 21     Pos[:,i]= walker()
#      22
#      23 plt.plot(Pos[0,:],Pos[1,:], "bo-")
#
# <ipython-input-57-94cb12790c57> in walker()
#       3     global x,y
#       4     eleccion=random.uniform(0,1)
# ----> 5     if r < 0.01: #un 1% de probbilidad de tomar un paso grande
#       6         x += np.random.normal(0,200)
#       7         y += random.gauss(0,200)
#
# NameError: name 'r' is not defined
